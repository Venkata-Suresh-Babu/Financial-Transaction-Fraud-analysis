# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# About the dataset

# %%
df = pd.read_csv("Fraud detection AIML Dataset.csv")
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
column_names =df.columns
print(f'Columns names in dataset:\n {column_names}')
# Out:
# Columns names in dataset:
#  Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
duplicates =df.duplicated().sum()
if duplicates > 0:
    print(f"Number of duplicate rows: {duplicates}")
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
null_values = df.isnull().sum()
if null_values.any():
    print("Missing values found:")
    print(null_values)
else:
    print("No missing values found.")
# Out:
# No missing values found.

# %% [markdown]
# Exploratory Data Analysis

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
isFraudPercentage = round(df['isFraud'].value_counts()[1] / df.shape[0] * 100, 2) * 100
print(isFraudPercentage)
# Out:
# 13.0

# %%
df['type'].value_counts().plot(kind='bar', title = "Tansaction types", color = 'violet', figsize = (8,5))
plt.xlabel('Transaction types')
plt.ylabel('Count')
plt.show()

# %%
fraud_by_type = df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_by_type.plot(kind = 'bar', title = 'Type of Fraud', color = 'indigo')
plt.xlabel('Type of Transaction')
plt.ylabel('Fraud Rate')
plt.show()

# %%
df['amount'].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
log = np.log1p(df['amount'])
sns.histplot(log, bins = 100, kde=True, color='green')
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Log (Amount + 1)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(data = df[df['amount'] < 50000], x = 'isFraud', y='amount')
plt.title('Amount vs isFraud (filterd usnder 50K)')
plt.show()

# %%
df['BalanceDiffOrginal'] = df['oldbalanceOrg'] - df['newbalanceOrig']
df['BalanceDiffDest'] =  df['oldbalanceDest'] - df['newbalanceDest']

# %%
(df['BalanceDiffOrginal'] < 0).sum()
# Out:
# np.int64(1399253)

# %%
(df['BalanceDiffDest'] < 0).sum()
# Out:
# np.int64(2806464)

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    BalanceDiffOrginal  BalanceDiffDest
# 0             9839.64              0.0
# 1             1864.28              0.0

# %%
frauds_per_step = df[df['isFraud'] == 1]['step'].value_counts().sort_index()
plt.plot(frauds_per_step.index, frauds_per_step.values, label = 'Frauds per step')
plt.xlabel('step (Time)')
plt.ylabel('No. Of Frauds')
plt.title('Frauds over time')
plt.grid(True)
plt.show()

# %%
#df.drop(columns='step', inplace=True)

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    BalanceDiffOrginal  BalanceDiffDest
# 0             9839.64              0.0
# ...

# %%
top_senders = df['nameOrig'].value_counts().head(10)
top_senders
# Out:
# nameOrig
# C1677795071    3
# C1999539787    3
# C724452879     3
# C1976208114    3
# C400299098     3
# C1784010646    3
# C1530544995    3
# C1065307291    3
# C545315117     3
# C1902386530    3
# Name: count, dtype: int64

# %%
fraud_users = df[df['isFraud'] == 1]['nameOrig'].value_counts().head(10)
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df['type'].isin(['TRANSFER', 'CASH_OUT'])]

# %%
fraud_types['type'].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_types, x= 'type', hue = 'isFraud')
plt.title('Fraud Distribution in Transfer and Cash out')
plt.show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'BalanceDiffOrginal', 'BalanceDiffDest'],
#       dtype='object')

# %%
corr = df[['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest', 'isFraud']].corr()
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
zero_after_transfer = df[
    (df['oldbalanceDest'] > 0) &
    (df['newbalanceDest'] == 0) &
    (df['type'].isin(['TRANSFER', 'CASH_OUT']))
]

# %%
zero_after_transfer
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 3           1  CASH_OUT     181.00   C840083671         181.00
# 19          1  TRANSFER  215310.30  C1670993182         705.00
# 51          1  CASH_OUT   23261.30  C2072313080       20411.53
# 70          1  CASH_OUT   47458.86   C527211736      209534.84
# 71          1  CASH_OUT  136872.92  C1533123860      162075.98
# ...       ...       ...        ...          ...            ...
# 6234408   594  CASH_OUT   46674.47  C2037671042       21183.00
# 6248887   596  CASH_OUT  164418.19  C1682514010       15011.00
# 6264447   612  CASH_OUT   35155.74   C869768672       16778.00
# 6314788   687  CASH_OUT   28062.81  C1090414984       31512.00
# 6342045   692  CASH_OUT   55060.60  C2066189247         425.00
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 3                  0.00    C38997010        21182.00             0.0        1
# ...

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    BalanceDiffOrginal  BalanceDiffDest
# 0             9839.64              0.0
# ...

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'BalanceDiffOrginal', 'BalanceDiffDest'],
#       dtype='object')

# %%
df_model = df.drop(['nameOrig', 'nameDest', 'isFlaggedFraud'], axis= 1)
df_model.head(10)
# Out:
#    step      type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1   PAYMENT   9839.64      170136.00       160296.36             0.0
# 1     1   PAYMENT   1864.28       21249.00        19384.72             0.0
# 2     1  TRANSFER    181.00         181.00            0.00             0.0
# 3     1  CASH_OUT    181.00         181.00            0.00         21182.0
# 4     1   PAYMENT  11668.14       41554.00        29885.86             0.0
# 5     1   PAYMENT   7817.71       53860.00        46042.29             0.0
# 6     1   PAYMENT   7107.77      183195.00       176087.23             0.0
# 7     1   PAYMENT   7861.64      176087.23       168225.59             0.0
# 8     1   PAYMENT   4024.36        2671.00            0.00             0.0
# 9     1     DEBIT   5337.77       41720.00        36382.23         41898.0
#
#    newbalanceDest  isFraud  BalanceDiffOrginal  BalanceDiffDest
# 0            0.00        0             9839.64             0.00
# ...

# %%
df_model.columns
# Out:
# Index(['step', 'type', 'amount', 'oldbalanceOrg', 'newbalanceOrig',
#        'oldbalanceDest', 'newbalanceDest', 'isFraud', 'BalanceDiffOrginal',
#        'BalanceDiffDest'],
#       dtype='object')

# %%
catergorical = ['type']
numeric = ['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest','newbalanceDest']

# %%
y = df_model['isFraud']
x = df_model.drop('isFraud', axis = 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %%
preprocessor = ColumnTransformer(
    transformers= [
        ('num', StandardScaler(), numeric),
        ('cat', OneHotEncoder(drop='first'), catergorical)
    ], remainder='drop'
)

# %%
pipeline  = Pipeline([
    ('prep', preprocessor),
    ('clf', LogisticRegression(class_weight='balanced', max_iter=1000))
])

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.94      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1805054,  101268],
#        [    159,    2305]])

# %%
score = pipeline.score(x_test, y_test) * 100
print(score)
# Out:
# 94.68630847040998

# %%
import joblib
joblib.dump(pipeline, 'fraud_detection_pipeline.pkl')
# Out:
# ['fraud_detection_pipeline.pkl']
